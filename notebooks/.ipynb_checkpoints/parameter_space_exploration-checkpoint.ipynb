# %%
import sys
sys.path.append('..')

import src as odyn
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt 

import geopandas as gpd
from shapely.geometry import Point, Polygon, MultiPolygon, shape
from pyproj import Proj

# %%
model = odyn.OpinionNetworkModel(probabilities = [.45,.1,.45], track_network_stats = True)
model.populate_model(num_agents = 1000, show_plot = True)
sim = odyn.NetworkSimulation()
sim.run_simulation(model = model,
           store_results = True
          )
sim.plot_simulation_results()
plt.savefig('sim_results_mid.png')

# %%
odyn.plot_mean_degree(sim.results)
plt.savefig('sim_mean_degree_mid.png')

# %%
odyn.plot_mean_beliefs(sim.results)
plt.savefig('sim_mean_val.png')

# %%
model = odyn.OpinionNetworkModel(probabilities = [.75,.15,.1])
model.populate_model(num_agents = 1000, show_plot = True)
sim = odyn.NetworkSimulation()
sim.run_simulation(model = model,
           store_results = True
          )
sim.plot_simulation_results()
plt.savefig('sim_results.png')

# %%
odyn.plot_mean_beliefs(sim.results)
plt.savefig('sim_mean_val.png')

# %%
model = odyn.OpinionNetworkModel(probabilities = [.1,.15,.75])
model.populate_model(num_agents = 1000, show_plot = True)
sim = odyn.NetworkSimulation()
sim.run_simulation(model = model,
           store_results = True
          )
sim.plot_simulation_results()
plt.savefig('sim_results.png')

# %%
odyn.plot_mean_beliefs(sim.results)
plt.savefig('sim_mean_val.png')

# %%
model = odyn.OpinionNetworkModel(probabilities = [.45,.1,.45], importance_of_distance = 0.1, track_network_stats = False)
model.populate_model(num_agents = 1000, show_plot = False)
sim = odyn.NetworkSimulation()
sim.run_simulation(model = model,
                   store_results = True)
sim.plot_simulation_results()
plt.savefig('sim_results.png')

# %%
odyn.plot_mean_beliefs(sim.results)
plt.savefig('sim_mean_val.png')

# %%
model = odyn.OpinionNetworkModel(probabilities = [.75,.15,.1], importance_of_distance = 0.1, track_network_stats = False)
model.populate_model(num_agents = 1000, show_plot = False)
sim = odyn.NetworkSimulation()
sim.run_simulation(model = model,
                   store_results = True)
sim.plot_simulation_results()
plt.savefig('sim_results.png')

# %%
odyn.plot_mean_beliefs(sim.results)
plt.savefig('sim_mean_val.png')

# %%
model = odyn.OpinionNetworkModel(probabilities = [.1,.15,.75], importance_of_distance = 0.1, track_network_stats = False)
model.populate_model(num_agents = 1000, show_plot = False)
sim = odyn.NetworkSimulation()
sim.run_simulation(model = model,
                   store_results = True)
sim.plot_simulation_results()
plt.savefig('sim_results.png')

# %%
odyn.plot_mean_beliefs(sim.results)
plt.savefig('sim_mean_val.png')

# %%
model = odyn.OpinionNetworkModel(probabilities = [.45,.1,.45], importance_of_distance = 1, track_network_stats = False)
model.populate_model(num_agents = 1000, show_plot = False)
sim = odyn.NetworkSimulation()
sim.run_simulation(model = model,
                   store_results = True)
sim.plot_simulation_results()
plt.savefig('sim_results.png')

# %%
odyn.plot_mean_beliefs(sim.results)
plt.savefig('sim_mean_val.png')

# %%
model = odyn.OpinionNetworkModel(probabilities = [.75,.15,.1], importance_of_distance = 1, track_network_stats = False)
model.populate_model(num_agents = 1000, show_plot = False)
sim = odyn.NetworkSimulation()
sim.run_simulation(model = model,
                   store_results = True)
sim.plot_simulation_results()
plt.savefig('sim_results.png')

# %%
odyn.plot_mean_beliefs(sim.results)
plt.savefig('sim_mean_val.png')

# %%
model = odyn.OpinionNetworkModel(probabilities = [.1,.15,.75], importance_of_distance = 1, track_network_stats = False)
model.populate_model(num_agents = 1000, show_plot = False)
sim = odyn.NetworkSimulation()
sim.run_simulation(model = model,
                   store_results = True)
sim.plot_simulation_results()
plt.savefig('sim_results.png')

# %%
odyn.plot_mean_beliefs(sim.results)
plt.savefig('sim_mean_val.png')

# %%
model = odyn.OpinionNetworkModel(probabilities = [.45,.1,.45], importance_of_distance = 2, track_network_stats = False)
model.populate_model(num_agents = 1000, show_plot = False)
sim = odyn.NetworkSimulation()
sim.run_simulation(model = model,
                   store_results = True)
sim.plot_simulation_results()
plt.savefig('sim_results.png')

# %%
odyn.plot_mean_beliefs(sim.results)
plt.savefig('sim_mean_val.png')

# %%
model = odyn.OpinionNetworkModel(probabilities = [.75,.15,.1], importance_of_distance = 2, track_network_stats = False)
model.populate_model(num_agents = 1000, show_plot = False)
sim = odyn.NetworkSimulation()
sim.run_simulation(model = model,
                   store_results = True)
sim.plot_simulation_results()
plt.savefig('sim_results.png')

# %%
odyn.plot_mean_beliefs(sim.results)
plt.savefig('sim_mean_val.png')

# %%
model = odyn.OpinionNetworkModel(probabilities = [.1,.15,.75], importance_of_distance = 2, track_network_stats = False)
model.populate_model(num_agents = 1000, show_plot = False)
sim = odyn.NetworkSimulation()
sim.run_simulation(model = model,
                   store_results = True)
sim.plot_simulation_results()
plt.savefig('sim_results.png')

# %%
odyn.plot_mean_beliefs(sim.results)
plt.savefig('sim_mean_val.png')

# %%
model = odyn.OpinionNetworkModel(probabilities = [.45,.1,.45], importance_of_distance = 7, track_network_stats = False)
model.populate_model(num_agents = 1000, show_plot = False)
sim = odyn.NetworkSimulation()
sim.run_simulation(model = model,
                   store_results = True)
sim.plot_simulation_results()
plt.savefig('sim_results.png')

# %%
odyn.plot_mean_beliefs(sim.results)
plt.savefig('sim_mean_val.png')

# %%
model = odyn.OpinionNetworkModel(probabilities = [.75,.1,.15], importance_of_distance = 7, track_network_stats = False)
model.populate_model(num_agents = 1000, show_plot = False)
sim = odyn.NetworkSimulation()
sim.run_simulation(model = model,
                   store_results = True)
sim.plot_simulation_results()
plt.savefig('sim_results.png')

# %%
odyn.plot_mean_beliefs(sim.results)
plt.savefig('sim_mean_val.png')

# %%
model = odyn.OpinionNetworkModel(probabilities = [.1,.15,.75], importance_of_distance = 7, track_network_stats = False)
model.populate_model(num_agents = 1000, show_plot = False)
sim = odyn.NetworkSimulation()
sim.run_simulation(model = model,
                   store_results = True)
sim.plot_simulation_results()
plt.savefig('sim_results.png')

# %%
odyn.plot_mean_beliefs(sim.results)
plt.savefig('sim_mean_val.png')

# %%
model = odyn.OpinionNetworkModel(probabilities = [.45,.1,.45], importance_of_distance = 12, track_network_stats = False)
model.populate_model(num_agents = 1000, show_plot = False)
sim = odyn.NetworkSimulation()
sim.run_simulation(model = model,
                   store_results = True)
sim.plot_simulation_results()
plt.savefig('sim_results.png')

# %%
odyn.plot_mean_beliefs(sim.results)
plt.savefig('sim_mean_val.png')

# %%
model = odyn.OpinionNetworkModel(probabilities = [.75,.15,.1], importance_of_distance = 10, track_network_stats = False)
model.populate_model(num_agents = 1000, show_plot = False)
sim = odyn.NetworkSimulation()
sim.run_simulation(model = model,
                   store_results = True)
sim.plot_simulation_results()
plt.savefig('sim_results.png')

# %%
odyn.plot_mean_beliefs(sim.results)
plt.savefig('sim_mean_val.png')

# %%
model = odyn.OpinionNetworkModel(probabilities = [.1,.15,.75], importance_of_distance = 10, track_network_stats = False)
model.populate_model(num_agents = 1000, show_plot = False)
sim = odyn.NetworkSimulation()
sim.run_simulation(model = model,
                   store_results = True)
sim.plot_simulation_results()
plt.savefig('sim_results.png')

# %%
odyn.plot_mean_beliefs(sim.results)
plt.savefig('sim_mean_val.png')

# %%
model = odyn.OpinionNetworkModel(probabilities = [.325,.35,.325], openness_to_neighbors = 0.7, openness_to_influencers = 1, track_network_stats = True)
model.populate_model(num_agents = 1000, show_plot = False)
model.plot_initial_network()
plt.savefig('sim_stats_mid.png')
sim = odyn.NetworkSimulation()
sim.run_simulation(model = model,
           store_results = True
          )
sim.plot_simulation_results()
plt.savefig('sim_results_mid.png')

# %%
odyn.plot_mean_degree(sim.results)
plt.savefig('sim_mean_degree_mid.png')

# %%
odyn.plot_mean_beliefs(sim.results)
plt.savefig('sim_mean_val_mid.png')

# %%
odyn.plot_opinion_network(sim.results[-1])

# %%
model = odyn.OpinionNetworkModel(probabilities = [.75,.15,.1], distance_scaling_factor = 1/15, track_network_stats = False)
model.populate_model(num_agents = 1000, show_plot = False)
sim = odyn.NetworkSimulation()
sim.run_simulation(model = model,
           store_results = True
          )
sim.plot_simulation_results()
plt.savefig('sim_results_left.png')

# %%
odyn.plot_mean_beliefs(sim.results)
plt.savefig('sim_mean_val_left.png')

# %%
model = odyn.OpinionNetworkModel(probabilities = [.1,.15,.75], distance_scaling_factor = 1/15, track_network_stats = False)
model.populate_model(num_agents = 1000, show_plot = False)
sim = odyn.NetworkSimulation()
sim.run_simulation(model = model,
           store_results = True
          )
sim.plot_simulation_results()
plt.savefig('sim_results_right.png')

# %%
odyn.plot_mean_beliefs(sim.results)
plt.savefig('sim_mean_val_right.png')

# %%
model = odyn.OpinionNetworkModel(probabilities = [.325,.35,.325],
                                 openness_to_neighbors = 0.7,
                                 openness_to_influencers = 1,
                                 importance_of_distance = 10,
                                 track_network_stats = True)
model.populate_model(num_agents = 2000, show_plot = True, polygon = triangle_object)
sim = odyn.NetworkSimulation()
sim.run_simulation(model = model,
           store_results = True
          )
sim.plot_simulation_results()
odyn.plot_mean_beliefs(sim.results)

# %%
odyn.plot_mean_degree(sim.results)
plt.savefig('sim_mean_degree_mid.png')

# %%
sim.results[-1]['belief_df']["belief"].values
# Out:
# array([0.83523672, 1.00615165, 0.90344927, ..., 0.83434722, 0.95015324,
#        0.94856598])

# %%
odyn.plot_opinion_network(sim.results[-1])

# %%
triangle_object = Polygon([[0,0],[300,0], [450,150],[300,300],[0, 300]])
triangle_object

# %%
polygon_list = [[.9185963, .2967035],
[.9171371, .2943218],
[.9154205, .2931311],
[.9119015, .2918000],
[.9068375, .2917300],
[.9088974, .2934810],
[.9099274, .2954429],
[.9082966, .2980347],
[.9052067, .2998544],
[.9094982, .3005562],
[.9133606, .3004861],
[.9159355, .3000658],
[.9192829, .2981045],
[.9185963, .2967035]]
scaling_factor = 15000
for i in range(len(polygon_list)):
    polygon_list[i] = [polygon_list[i][0]*scaling_factor, polygon_list[i][1]*scaling_factor]
triangle_object = Polygon(polygon_list)
triangle_object

# %%
triangle_object = ball

# %%
triangle_object = Polygon([(30, 2.01), (31.91, 0.62), (31.18, -1.63), (28.82, -1.63), (28.09, 0.62)])

# %%
bnd = list(triangle_object.boundary.coords)
gdf = gpd.GeoDataFrame(geometry = [triangle_object])
gdf.crs = "EPSG:3857"
gdf = gdf.to_crs(epsg=4326)
co = list(gdf.loc[0,"geometry"].exterior.coords)
lon, lat = zip(*co)
pa = Proj(
    "+proj=aea +lat_1=37.0 +lat_2=41.0 +lat_0=39.0 +lon_0=-106.55")
x, y = pa(lon, lat)
coord_proj = {"type": "Polygon", "coordinates": [zip(x, y)]}
area = shape(coord_proj).area / (10 ** 6) # area in km^2
U = np.random.uniform(0,1, 5000 // (len(bnd) - 3))
V = np.random.uniform(0,1, 5000 // (len(bnd) - 3))

UU = np.where(U + V > 1, 1-U, U)
VV = np.where(U + V > 1, 1-V, V)
# Shift triangle into origin and and place points.
agents = []
for i in range(len(bnd) - 3):
    agent = ((UU.reshape(len(UU),-1) * (np.array(bnd[i + 2]) - np.array(bnd[0])).reshape(-1,2)) +
             (VV.reshape(len(VV),-1) * (np.array(bnd[i + 1]) - np.array(bnd[0])).reshape(-1,2)))
    agents.append(agent)

 # Shift points back to original position.
for i in range(len(agents)):
    agents[i] = agents[i] + np.array(bnd[0]).reshape(-1,2)

agents_df_list = []
for agent in agents:
    agent_df = pd.DataFrame(agent, columns = ["x", "y"])
    agents_df_list.append(agent_df)

agents_df = pd.concat(agents_df_list, axis=0, ignore_index = True)
odyn.plot_agents_on_triangle(triangle_object, agents_df)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 bnd = list(triangle_object.boundary.coords)
#       2 gdf = gpd.GeoDataFrame(geometry = [triangle_object])
#       3 gdf.crs = "EPSG:3857"
#
# File ~\miniconda3\envs\diamonds\lib\site-packages\shapely\geometry\base.py:954, in BaseMultipartGeometry.coords(self)
#     952 @property
#     953 def coords(self):
# --> 954     raise NotImplementedError(
#     955         "Multi-part geometries do not provide a coordinate sequence")
#
# NotImplementedError: Multi-part geometries do not provide a coordinate sequence

# %%
point = Point((0,0))
ball = point.buffer(1)
ball

# %%
border = [(-180, 90), (-180, -90), (180, -90), (180, 90)]
world = Polygon(shell=border)
hole = [[(-160, 70), (-160, -70), (160, -70), (160, 70)]]
frame = Polygon(shell=border, holes=hole)
triangle_object = frame
print(triangle_object.boundary)
# Out:
# MULTILINESTRING ((-180 90, -180 -90, 180 -90, 180 90, -180 90), (-160 70, -160 -70, 160 -70, 160 70, -160 70))

# %%
from numba import jit, cuda
import numpy as np
# to measure exec time
from timeit import default_timer as timer
# normal function to run on cpu
def func(a):                                
    for i in range(10000000):
        a[i]+= 1      
  
# function optimized to run on gpu 
# @jit(target ="cuda")      
@jit(nopython=True) 
def func2(a):
    for i in range(10000000):
        a[i]+= 1
if __name__=="__main__":
    n = 10000000                            
    a = np.ones(n, dtype = np.float64)
    b = np.ones(n, dtype = np.float32)
      
    start = timer()
    func(a)
    print("without GPU:", timer()-start)    
      
    start = timer()
    func2(a)
    print("with GPU:", timer()-start)
# Out:
# without GPU: 7.71380989998579
# with GPU: 0.6817515001166612

# %%
model = odyn.OpinionNetworkModel(probabilities = [.45,.1,.45])
model.populate_model(num_agents = 1000, show_plot = False, discrete = False)
sim = odyn.NetworkSimulation()
sim.run_simulation(model = model,
                   store_results = True)
sim.plot_simulation_results()
