# %%
import sys
sys.path.append('..')

import src as odyn
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt 

import geopandas as gpd
from shapely.geometry import Point, Polygon, MultiPolygon, shape
from pyproj import Proj

# %%
model = odyn.OpinionNetworkModel(probabilities = [.45,.1,.45])
model.populate_model(num_agents = 1000, show_plot = True)
sim = odyn.NetworkSimulation()
sim.run_simulation(model = model,
           store_results = True
          )
sim.plot_simulation_results()
plt.savefig('sim_results.png')

# %%
odyn.plot_mean_beliefs(sim.results)
plt.savefig('sim_mean_val.png')

# %%
model = odyn.OpinionNetworkModel(probabilities = [.75,.15,.1])
model.populate_model(num_agents = 1000, show_plot = True)
sim = odyn.NetworkSimulation()
sim.run_simulation(model = model,
           store_results = True
          )
sim.plot_simulation_results()
plt.savefig('sim_results.png')

# %%
odyn.plot_mean_beliefs(sim.results)
plt.savefig('sim_mean_val.png')

# %%
model = odyn.OpinionNetworkModel(probabilities = [.1,.15,.75])
model.populate_model(num_agents = 1000, show_plot = True)
sim = odyn.NetworkSimulation()
sim.run_simulation(model = model,
           store_results = True
          )
sim.plot_simulation_results()
plt.savefig('sim_results.png')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [4], in <cell line: 2>()
#       1 model = odyn.OpinionNetworkModel(probabilities = [1.,.15,.75])
# ----> 2 model.populate_model(num_agents = 1000, show_plot = True)
#       3 sim = odyn.NetworkSimulation()
#       4 sim.run_simulation(model = model,
#       5            store_results = True
#       6           )
#
# File ~\Desktop\DIAMONDS\ODyN\ODyN\notebooks\..\src\simulations.py:125, in OpinionNetworkModel.populate_model(self, num_agents, geo_df, bounding_box, show_plot)
#     119     agent_df = self.add_random_agents_to_triangles(geo_df = geo_df,
#     120                                                 bounding_box = bounding_box,
#     121                                                 show_plot = False)
#     123 logging.info("\n {} agents added.".format(agent_df.shape[0]))
# --> 125 belief_df = self.assign_weights_and_beliefs(agent_df)
#     126 logging.info("\n Weights and beliefs assigned.")
#     128 prob_df = self.compute_probability_array(belief_df)
#
# File ~\Desktop\DIAMONDS\ODyN\ODyN\notebooks\..\src\simulations.py:308, in OpinionNetworkModel.assign_weights_and_beliefs(self, agent_df, show_plot)
#     305 k = -1/(power_law_exponent)
#     306 modes = [i for i in range(len(self.probabilities))]
# --> 308 assert np.sum(np.array(self.probabilities)) == 1, "Probabilities must sum to 1."
#     310 belief_df["weight"] = np.random.uniform(0,1,belief_df.shape[0]) ** (k)
#     311 belief_df["belief"] = np.random.choice(modes, belief_df.shape[0],
#     312                         p = self.probabilities)
#
# AssertionError: Probabilities must sum to 1.

# %%
odyn.plot_mean_beliefs(sim.results)
plt.savefig('sim_mean_val.png')

# %%
model = odyn.OpinionNetworkModel(probabilities = [.45,.1,.45], power_law_exponent = 1)
model.populate_model(num_agents = 1000, show_plot = False)
sim = odyn.NetworkSimulation()
sim.run_simulation(model = model,
           store_results = True
          )
sim.plot_simulation_results()
plt.savefig('sim_results.png')

# %%
odyn.plot_mean_beliefs(sim.results)
plt.savefig('sim_mean_val.png')
